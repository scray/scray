# %%
from scray.job_client.client import ScrayJobClient 
from scray.job_client.config import ScrayJobClientConfig


config = ScrayJobClientConfig(
    sync_host_address = "https://sync.research.dev.example.com",
    sync_port = 443,
    sync_client_secret= "eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkphbmUgRG9lIiwiaWF0IjoxNzI5NDQwMDAwLCJleHAiOjE3Mjk0NDM2MDAsImlzcyI6ImF1dGguZXhhbXBsZS5jb20iLCJhdWQiOiJhcGkuZXhhbXBsZS5jb20iLCJzY29wZSI6InJlYWQ6dGhpbmdzIHdyaXRlOnRoaW5ncyJ9",
    sync_ca_cert_path = "ca.crt",

)

client = ScrayJobClient(config=config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 from scray.job_client.client import ScrayJobClient
#       2 from scray.job_client.config import ScrayJobClientConfig
# ----> 5 config = ScrayJobClientConfig(
#       6     sync_host_address = "https://sync.research.dev.seeburger.de",
#       7     sync_port = 443,
#       8     sync_client_secret= "eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkphbmUgRG9lIiwiaWF0IjoxNzI5NDQwMDAwLCJleHAiOjE3Mjk0NDM2MDAsImlzcyI6ImF1dGguZXhhbXBsZS5jb20iLCJhdWQiOiJhcGkuZXhhbXBsZS5jb20iLCJzY29wZSI6InJlYWQ6dGhpbmdzIHdyaXRlOnRoaW5ncyJ9",
#       9     sync_ca_cert_path = "ca.crt",
#      10
#      11 )
#      13 client = ScrayJobClient(config=config)
#
# TypeError: ScrayJobClientConfig.__init__() got an unexpected keyword argument 'sync_ca_cert_path'

# %%
client.get_latest_versioned_data("http://scray.org/ai/app/env/see/os/k8s", "RUNNING")
