# %%
from scray.job_client.client import ScrayJobClient 
from scray.job_client.config import ScrayJobClientConfig


config = ScrayJobClientConfig(
  host_address = "http://localhost",
  port = 8082
)

client = ScrayJobClient(config=config)

# %%
client.get_latest_versioned_data("http://scray.org/ai/app/env/see/os/k8s", "RUNNING")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client.get_latest_versioned_data("http://scray.org/ai/app/env/see/os/k8s", "RUNNING")
#
# AttributeError: 'ScrayJobClient' object has no attribute 'get_latest_versioned_data'
